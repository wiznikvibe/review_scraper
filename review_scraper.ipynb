# %% [markdown]
# ### Review Scraper
#
# Go to flipkart > search for product > Extract review and the rating associated with it
#
# Why this?
#
#         - Can be used for building sentiment analysis and machine learning models
#
#         - Helps building data set from scratch, also for building data creation pipeline.
#
#         - For NLP Projects, To understand the public opinion about certain products
#
# Steps-
#
#         -  Search for > Product
#
#         -  Html > View Page Source> Right Click on the browser
#
#         -  Look for the html tags with the required information and fetch them  using bs4 and requests library.

# %%
# Import Libraries
from bs4 import BeautifulSoup as bs 
from urllib.request import urlopen as urReq
import requests

# %%
# Search for Products for data gathering 
flipkart_url= "https://www.flipkart.com/search?q="

# %%
product = "nothing phone 1"
query = product.replace(" ","")

# %%
# urReq returns the html page sorce for the url passed 
response_web = urReq(flipkart_url+query)
response_web

# %%
# Make the Html page readable  
data = bs(response_web, 'html.parser')
data
# Out:
# <!DOCTYPE html>
# ...

# %%
# find_all is used for finding the desired html objects and associated tags 
containers = data.find_all("div", {"class":"_1AtVbE col-12-12"})
containers
# Out:
# [<div class="_1AtVbE col-12-12"><div class="_1KOcBL"><section class="JWMl0H _2hbLCH"><div class="_2ssEMF"><div class="_3V8rao"><span>Filters</span></div></div></section><div class="_2q_g77"><section class="_2aDURW"><div class="_2lfNTw"><span>CATEGORIES</span></div><div><div class="TB_InB"><span><svg class="_2Iqv73" height="10" viewbox="0 0 16 27" width="10" xmlns="http://www.w3.org/2000/svg"><path class="_3zK8He" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff"></path></svg></span><a class="_2qvBBJ _2Mji8F" href="/mobiles-accessories/pr?sid=tyy&amp;q=nothingphone1&amp;otracker=categorytree" title="Mobiles &amp; Accessories">Mobiles &amp; Accessories</a></div></div><div><div class="TB_InB"><span><svg class="_2Iqv73" height="10" viewbox="0 0 16 27" width="10" xmlns="http://www.w3.org/2000/svg"><path class="" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff"></path></svg></span><a class="_1jJQdf _2Mji8F" href="/mobiles/pr?si
# ...

# %%
product_end = []
for i in containers[2:12]:
    product_end.append(i.div.div.div.a['href'])

# %%
# Looks for tags with the product name
flipkart_url+product_end[0]
# Out:
# 'https://www.flipkart.com/search?q=/nothing-phone-1-black-256-gb/p/itmeea53a564de47?pid=MOBGCYGPWXYRRNB4&lid=LSTMOBGCYGPWXYRRNB426WTZ8&marketplace=FLIPKART&q=nothingphone1&store=tyy%2F4io&srno=s_1_1&otracker=search&fm=organic&iid=de44fe1c-e4d6-4fb8-8de4-aa63f2da1eea.MOBGCYGPWXYRRNB4.SEARCH&ppt=None&ppn=None&ssid=u10vai0d6o0000001691146019385&qH=c2d3eb86d08753da'

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\Users\nikhi\review_scraper\test.ipynb Cell 11 in <cell line: 2>()
#       <a href='vscode-notebook-cell:/c%3A/Users/nikhi/review_scraper/test.ipynb#X42sZmlsZQ%3D%3D?line=0'>1</a> product_end = []
#       <a href='vscode-notebook-cell:/c%3A/Users/nikhi/review_scraper/test.ipynb#X42sZmlsZQ%3D%3D?line=1'>2</a> for i in containers[2:26]:
# ----> <a href='vscode-notebook-cell:/c%3A/Users/nikhi/review_scraper/test.ipynb#X42sZmlsZQ%3D%3D?line=2'>3</a>     product_end.append(i.div.div.div.a['href'])
#
# AttributeError: 'NoneType' object has no attribute 'div'

# %%
product_end[0]

# %%
product_0 = requests.get(flipkart_url+product_end[0])
product_0

# %%
# enconding the url in order to pass it through a html parser for extracting reviews and ratings 
product_0.encoding = 'utf-8'

# %%
product_0_page = bs(product_0.text,'html.parser')
product_0_page

# %%
# Listing all the reviews 
product_0_page.find_all('div',{'class':"_16PBlm"})

# %%
review_end = product_0_page.find_all('div',{'class':'col JOpGWq'})

# %%
reviews_page =

# %%
product_3_page.find_all('div',{"class":"_30jeq3 _16Jk6d"})[0].text

# %%
for i in range(len(all_review)-1):

    price = product_3_page.find_all('div',{"class":"_30jeq3 _16Jk6d"})[0].text
    offer = product_3_page.find_all('div',{"class":"_1V_ZGU"})[0].text
    highlights = product_3_page.find_all('div',{"class":"_2418kt"})[0].text
    rating = all_review[i].text[0]
   
    customer_names = all_review[i].find_all('p',{"class":"_2sc7ZR _2V5EHH"})[0].text
    
    
    comment_head = all_review[i].find_all('p',{'class':"_2-N8zT"})[0].text

    date_of_post = all_review[i].find_all('p',{'class':'_2sc7ZR'})[1].text
    
    review = all_review[i].div.find_all('div',{"class":""})[0].div.text
    # print(review)
    print(f"Customer Name: {customer_name} || Rating:", rating")
    # print()

# %%
# Review By: Name 
name = all_review[5].div.div.find_all('p',{"class":"_2sc7ZR _2V5EHH"})[0].text

# %%
# Review Header 
comment_header = all_review[5].find_all('p',{'class':"_2-N8zT"})[0].text
comment_header

# %%
# Review 
review = all_review[5].div.find_all('div',{"class":""})[0].div.text

# %%
# Date of Review Posted 
date = all_review[5].div.find_all('p',{'class':'_2sc7ZR'})[1].text

# %%
all_review[7].div.find_all('p',{'class':'_2mcZGG'})[0].text.split()

# %%
location.strip("Certified Buyer, ")

# %%
# Price for Product
price = product_3_page.find_all('div',{"class":"_30jeq3 _16Jk6d"})[0].text

# %%
# Offer for the product 
offer = product_3_page.find_all('div',{"class":"_1V_ZGU"})[0].text

# %%
# Product Highlights 
highlights = product_3_page.find_all('div',{"class":"_2418kt"})[0].text

# %%
# 1:36:17
